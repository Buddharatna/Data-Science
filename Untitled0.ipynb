# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10a1fc62-ef1c-46d2-b409-9b9f0a249173" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10a1fc62-ef1c-46d2-b409-9b9f0a249173">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving albumlist.csv to albumlist.csv

# %%
import csv
with open('albumlist.csv','r') as csvfile:
  reader = csv.DictReader(csvfile)

  print(type(reader))
  print(reader.fieldnames)
# Out:
# <class 'csv.DictReader'>
# ['Number', 'Year', 'Album', 'Artist', 'Genre', 'Subgenre']

# %%
with open('albumlist.csv','r') as csvfile:
  reader = csv.DictReader(csvfile)

  for row in reader:
    print(row)
# Out:
# OrderedDict([('Number', '1'), ('Year', '1967'), ('Album', "Sgt. Pepper's Lonely Hearts Club Band"), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Psychedelic Rock')])
# OrderedDict([('Number', '2'), ('Year', '1966'), ('Album', 'Pet Sounds'), ('Artist', 'The Beach Boys'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Psychedelic Rock')])
# OrderedDict([('Number', '3'), ('Year', '1966'), ('Album', 'Revolver'), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Pop Rock')])
# OrderedDict([('Number', '4'), ('Year', '1965'), ('Album', 'Highway 61 Revisited'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Blues Rock')])
# OrderedDict([('Number', '5'), ('Year', '1965'), ('Album', 'Rubber Soul'), ('Artist', 'The Beatles'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '6'), ('Year', '1971'), ('Album', "What's Going On"), ('Artist', 'Marvin Gaye'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '7'), ('Year', '1972'), ('Album', 'Exile on Main St.'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Rock & Roll, Classic Rock')])
# OrderedDict([('Number', '8'), ('Year', '1979'), ('Album', 'London Calling'), ('Artist', 'The Clash'), ('Genre', 'Rock'), ('Subgenre', 'Punk, New Wave')])
# OrderedDict([('Number', '9'), ('Year', '1966'), ('Album', 'Blonde on Blonde'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Folk Rock, Rhythm & Blues')])
# OrderedDict([('Number', '10'), ('Year', '1968'), ('Album', 'The Beatles ("The White Album")'), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Pop Rock, Psychedelic Rock, Experimental')])
# OrderedDict([('Number', '11'), ('Year', '1976'), ('Album', 'The Sun Sessions'), ('Artist', 'Elvis Presley'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll')])
# OrderedDict([('Number', '12'), ('Year', '1959'), ('Album', 'Kind of Blue'), ('Artist', 'Miles Davis'), ('Genre', 'Jazz'), ('Subgenre', 'Modal')])
# OrderedDict([('Number', '13'), ('Year', '1967'), ('Album', 'The Velvet Underground & Nico'), ('Artist', 'The Velvet Underground'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock, Art Rock, Experimental')])
# OrderedDict([('Number', '14'), ('Year', '1969'), ('Album', 'Abbey Road'), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Classic Rock, Pop Rock')])
# OrderedDict([('Number', '15'), ('Year', '1967'), ('Album', 'Are You Experienced'), ('Artist', 'The Jimi Hendrix Experience'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock, Psychedelic Rock')])
# OrderedDict([('Number', '16'), ('Year', '1975'), ('Album', 'Blood on the Tracks'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Acoustic, Ballad')])
# OrderedDict([('Number', '17'), ('Year', '1991'), ('Album', 'Nevermind'), ('Artist', 'Nirvana'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Grunge')])
# OrderedDict([('Number', '18'), ('Year', '1975'), ('Album', 'Born to Run'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '19'), ('Year', '1968'), ('Album', 'Astral Weeks'), ('Artist', 'Van Morrison'), ('Genre', 'Jazz, Rock, Blues, Folk, World, & Country'), ('Subgenre', 'Acoustic, Classic Rock, Free Improvisation')])
# OrderedDict([('Number', '20'), ('Year', '1982'), ('Album', 'Thriller'), ('Artist', 'Michael Jackson'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'Disco')])
# OrderedDict([('Number', '21'), ('Year', '1982'), ('Album', 'The Great Twenty_Eight'), ('Artist', 'Chuck Berry'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll')])
# OrderedDict([('Number', '22'), ('Year', '1990'), ('Album', 'The Complete Recordings'), ('Artist', 'Robert Johnson'), ('Genre', 'Blues'), ('Subgenre', 'Delta Blues')])
# OrderedDict([('Number', '23'), ('Year', '1970'), ('Album', 'John Lennon/Plastic Ono Band'), ('Artist', 'John Lennon / Plastic Ono Band'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '24'), ('Year', '1973'), ('Album', 'Innervisions'), ('Artist', 'Stevie Wonder'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '25'), ('Year', '1963'), ('Album', 'Live at the Apollo, 1962'), ('Artist', 'James Brown'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Soul')])
# OrderedDict([('Number', '26'), ('Year', '1977'), ('Album', 'Rumours'), ('Artist', 'Fleetwood Mac'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '27'), ('Year', '1987'), ('Album', 'The Joshua Tree'), ('Artist', 'U2'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Pop Rock')])
# OrderedDict([('Number', '28'), ('Year', '1971'), ('Album', "Who's Next"), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Mod, Prog Rock, Psychedelic Rock')])
# OrderedDict([('Number', '29'), ('Year', '1969'), ('Album', 'Led Zeppelin'), ('Artist', 'Led Zeppelin'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Hard Rock')])
# OrderedDict([('Number', '30'), ('Year', '1971'), ('Album', 'Blue'), ('Artist', 'Joni Mitchell'), ('Genre', 'Pop'), ('Subgenre', 'Acoustic, Ballad, Folk')])
# OrderedDict([('Number', '31'), ('Year', '1965'), ('Album', 'Bringing It All Back Home'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Folk')])
# OrderedDict([('Number', '32'), ('Year', '1969'), ('Album', 'Let It Bleed'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Hard Rock')])
# OrderedDict([('Number', '33'), ('Year', '1976'), ('Album', 'Ramones'), ('Artist', 'Ramones'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Punk')])
# OrderedDict([('Number', '34'), ('Year', '1968'), ('Album', 'Music From Big Pink'), ('Artist', 'The Band'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Acoustic, Blues Rock')])
# OrderedDict([('Number', '35'), ('Year', '1972'), ('Album', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), ('Artist', 'David Bowie'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Glam')])
# OrderedDict([('Number', '36'), ('Year', '1971'), ('Album', 'Tapestry'), ('Artist', 'Carole King'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Folk Rock, Soft Rock')])
# OrderedDict([('Number', '37'), ('Year', '1976'), ('Album', 'Hotel California'), ('Artist', 'Eagles'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '38'), ('Year', '2001'), ('Album', 'The Anthology'), ('Artist', 'Muddy Waters'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Folk')])
# OrderedDict([('Number', '39'), ('Year', '1963'), ('Album', 'Please Please Me'), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Beat, Rock & Roll')])
# OrderedDict([('Number', '40'), ('Year', '1967'), ('Album', 'Forever Changes'), ('Artist', 'Love'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Psychedelic Rock')])
# OrderedDict([('Number', '41'), ('Year', '1977'), ('Album', "Never Mind the Bollocks Here's the Sex Pistols"), ('Artist', 'Sex Pistols'), ('Genre', 'Rock'), ('Subgenre', 'Punk')])
# OrderedDict([('Number', '42'), ('Year', '1967'), ('Album', 'The Doors'), ('Artist', 'The Doors'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock')])
# OrderedDict([('Number', '43'), ('Year', '1973'), ('Album', 'The Dark Side of the Moon'), ('Artist', 'Pink Floyd'), ('Genre', 'Rock'), ('Subgenre', 'Prog Rock')])
# OrderedDict([('Number', '44'), ('Year', '1975'), ('Album', 'Horses'), ('Artist', 'Patti Smith'), ('Genre', 'Rock'), ('Subgenre', 'Art Rock')])
# OrderedDict([('Number', '45'), ('Year', '1969'), ('Album', 'The Band ("The Brown Album")'), ('Artist', 'The Band'), ('Genre', 'Classical, Stage & Screen'), ('Subgenre', 'Soundtrack, Modern Classical, Contemporary, Score')])
# OrderedDict([('Number', '46'), ('Year', '1984'), ('Album', 'Legend: The Best of Bob Marley and The Wailers'), ('Artist', 'Bob Marley & The Wailers'), ('Genre', 'Reggae'), ('Subgenre', 'Reggae, Roots Reggae')])
# OrderedDict([('Number', '47'), ('Year', '1965'), ('Album', 'A Love Supreme'), ('Artist', 'John Coltrane'), ('Genre', 'Jazz'), ('Subgenre', 'Free Jazz, Hard Bop, Modal')])
# OrderedDict([('Number', '48'), ('Year', '1988'), ('Album', 'It Takes a Nation of Millions to Hold Us Back'), ('Artist', 'Public Enemy'), ('Genre', 'Hip Hop'), ('Subgenre', 'Conscious')])
# OrderedDict([('Number', '49'), ('Year', '1971'), ('Album', 'At Fillmore East'), ('Artist', 'The Allman Brothers Band'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '50'), ('Year', '1957'), ('Album', "Here's Little Richard"), ('Artist', 'Little Richard'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Rock & Roll, Rhythm & Blues')])
# OrderedDict([('Number', '51'), ('Year', '1970'), ('Album', 'Bridge Over Troubled Water'), ('Artist', 'Simon & Garfunkel'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Classic Rock')])
# OrderedDict([('Number', '52'), ('Year', '1975'), ('Album', 'Greatest Hits'), ('Artist', 'Al Green'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '53'), ('Year', '1964'), ('Album', 'Meet The Beatles!'), ('Artist', 'The Beatles'), ('Genre', 'Rock'), ('Subgenre', 'Beat, Rock & Roll')])
# OrderedDict([('Number', '54'), ('Year', '1991'), ('Album', 'The Birth of Soul'), ('Artist', 'Ray Charles'), ('Genre', 'Jazz, Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Big Band, Soul, Soul-Jazz')])
# OrderedDict([('Number', '55'), ('Year', '1968'), ('Album', 'Electric Ladyland'), ('Artist', 'The Jimi Hendrix Experience'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Electric Blues, Psychedelic Rock')])
# OrderedDict([('Number', '56'), ('Year', '1956'), ('Album', 'Elvis Presley'), ('Artist', 'Elvis Presley'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Rockabilly')])
# OrderedDict([('Number', '57'), ('Year', '1976'), ('Album', 'Songs in the Key of Life'), ('Artist', 'Stevie Wonder'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul, Disco')])
# OrderedDict([('Number', '58'), ('Year', '1968'), ('Album', 'Beggars Banquet'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock, Funk / Soul, Pop'), ('Subgenre', 'Blues Rock, Southern Rock, Classic Rock')])
# OrderedDict([('Number', '59'), ('Year', '1976'), ('Album', 'Chronicle: The 20 Greatest Hits'), ('Artist', 'Creedence Clearwater Revival'), ('Genre', 'Rock'), ('Subgenre', 'None')])
# OrderedDict([('Number', '60'), ('Year', '1969'), ('Album', 'Trout Mask Replica'), ('Artist', 'Captain Beefheart & His Magic Band'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Dialogue, Field Recording, Avantgarde, Electric Blues, Psychedelic Rock, Experimental')])
# OrderedDict([('Number', '61'), ('Year', '1970'), ('Album', 'Greatest Hits'), ('Artist', 'Sly & The Family Stone'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Funk')])
# OrderedDict([('Number', '62'), ('Year', '1987'), ('Album', 'Appetite for Destruction'), ('Artist', "Guns N' Roses"), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Heavy Metal')])
# OrderedDict([('Number', '63'), ('Year', '1991'), ('Album', 'Achtung Baby'), ('Artist', 'U2'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Pop Rock, Synth-pop, Alternative Rock, Arena Rock')])
# OrderedDict([('Number', '64'), ('Year', '1971'), ('Album', 'Sticky Fingers'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '65'), ('Year', '1991'), ('Album', 'Back to Mono (1958-1969)'), ('Artist', 'Phil Spector'), ('Genre', 'Rock, Funk / Soul, Pop'), ('Subgenre', 'Doo Wop, Pop Rock, Ballad, Rhythm & Blues')])
# OrderedDict([('Number', '66'), ('Year', '1970'), ('Album', 'Moondance'), ('Artist', 'Van Morrison'), ('Genre', 'Jazz, Rock, Funk / Soul, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Rhythm & Blues, Classic Rock, Contemporary Jazz')])
# OrderedDict([('Number', '67'), ('Year', '2000'), ('Album', 'Kid A'), ('Artist', 'Radiohead'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Alternative Rock, IDM, Experimental')])
# OrderedDict([('Number', '68'), ('Year', '1979'), ('Album', 'Off the Wall'), ('Artist', 'Michael Jackson'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'Disco, Soul, Ballad')])
# OrderedDict([('Number', '69'), ('Year', '1971'), ('Album', '[Led Zeppelin IV]'), ('Artist', 'Led Zeppelin'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Classic Rock, Blues Rock')])
# OrderedDict([('Number', '70'), ('Year', '1977'), ('Album', 'The Stranger'), ('Artist', 'Billy Joel'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '71'), ('Year', '1986'), ('Album', 'Graceland'), ('Artist', 'Paul Simon'), ('Genre', 'Jazz, Rock, Funk / Soul, Pop, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Pop Rock, African, Afrobeat, Zydeco, Funk, Rhythm & Blues')])
# OrderedDict([('Number', '72'), ('Year', '1972'), ('Album', 'Superfly'), ('Artist', 'Curtis Mayfield'), ('Genre', 'Funk / Soul, Stage & Screen'), ('Subgenre', 'Soundtrack, Soul')])
# OrderedDict([('Number', '73'), ('Year', '1975'), ('Album', 'Physical Graffiti'), ('Artist', 'Led Zeppelin'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '74'), ('Year', '1970'), ('Album', 'After the Gold Rush'), ('Artist', 'Neil Young'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Country Rock')])
# OrderedDict([('Number', '75'), ('Year', '1991'), ('Album', 'Star Time'), ('Artist', 'James Brown'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul, Funk, Disco')])
# OrderedDict([('Number', '76'), ('Year', '1984'), ('Album', 'Purple Rain'), ('Artist', 'Prince and the Revolution'), ('Genre', 'Electronic, Rock, Funk / Soul, Stage & Screen'), ('Subgenre', 'Pop Rock, Funk, Soundtrack, Synth-pop')])
# OrderedDict([('Number', '77'), ('Year', '1980'), ('Album', 'Back in Black'), ('Artist', 'AC/DC'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock')])
# OrderedDict([('Number', '78'), ('Year', '1965'), ('Album', 'Otis Blue: Otis Redding Sings Soul'), ('Artist', 'Otis Redding'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '79'), ('Year', '1969'), ('Album', 'Led Zeppelin II'), ('Artist', 'Led Zeppelin'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Classic Rock, Hard Rock')])
# OrderedDict([('Number', '80'), ('Year', '1971'), ('Album', 'Imagine'), ('Artist', 'John Lennon'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '81'), ('Year', '1977'), ('Album', 'The Clash'), ('Artist', 'The Clash'), ('Genre', 'Rock'), ('Subgenre', 'Punk')])
# OrderedDict([('Number', '82'), ('Year', '1972'), ('Album', 'Harvest'), ('Artist', 'Neil Young'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Country Rock, Classic Rock')])
# OrderedDict([('Number', '83'), ('Year', '1967'), ('Album', 'Axis: Bold as Love'), ('Artist', 'The Jimi Hendrix Experience'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Electric Blues')])
# OrderedDict([('Number', '84'), ('Year', '1967'), ('Album', 'I Never Loved a Man the Way I Love You'), ('Artist', 'Aretha Franklin'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '85'), ('Year', '1968'), ('Album', 'Lady Soul'), ('Artist', 'Aretha Franklin'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '86'), ('Year', '1984'), ('Album', 'Born in the U.S.A.'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '87'), ('Year', '1979'), ('Album', 'The Wall'), ('Artist', 'Pink Floyd'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Prog Rock')])
# OrderedDict([('Number', '88'), ('Year', '1968'), ('Album', 'At Folsom Prison'), ('Artist', 'Johnny Cash'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country')])
# OrderedDict([('Number', '89'), ('Year', '1969'), ('Album', 'Dusty in Memphis'), ('Artist', 'Dusty Springfield'), ('Genre', 'Rock, Funk / Soul'), ('Subgenre', 'Pop Rock, Soul')])
# OrderedDict([('Number', '90'), ('Year', '1972'), ('Album', 'Talking Book'), ('Artist', 'Stevie Wonder'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul, Funk')])
# OrderedDict([('Number', '91'), ('Year', '1973'), ('Album', 'Goodbye Yellow Brick Road'), ('Artist', 'Elton John'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Classic Rock')])
# OrderedDict([('Number', '92'), ('Year', '1978'), ('Album', '20 Golden Greats'), ('Artist', 'Buddy Holly'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll')])
# OrderedDict([('Number', '93'), ('Year', '1987'), ('Album', 'Sign "Peace" the Times'), ('Artist', 'Prince'), ('Genre', 'Rock, Reggae'), ('Subgenre', 'Ska, Reggae-Pop')])
# OrderedDict([('Number', '94'), ('Year', '1984'), ('Album', '40 Greatest Hits'), ('Artist', 'Hank Williams'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country')])
# OrderedDict([('Number', '95'), ('Year', '1970'), ('Album', 'Bitches Brew'), ('Artist', 'Miles Davis'), ('Genre', 'Jazz'), ('Subgenre', 'Fusion')])
# OrderedDict([('Number', '96'), ('Year', '1969'), ('Album', 'Tommy'), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock')])
# OrderedDict([('Number', '97'), ('Year', '1963'), ('Album', "The Freewheelin' Bob Dylan"), ('Artist', 'Bob Dylan'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Folk')])
# OrderedDict([('Number', '98'), ('Year', '1978'), ('Album', "This Year's Model"), ('Artist', 'Elvis Costello'), ('Genre', 'Rock'), ('Subgenre', 'New Wave')])
# OrderedDict([('Number', '99'), ('Year', '1971'), ('Album', "There's a Riot Goin' On"), ('Artist', 'Sly & The Family Stone'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Funk')])
# OrderedDict([('Number', '100'), ('Year', '1968'), ('Album', 'Odessey and Oracle'), ('Artist', 'The Zombies'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock')])
# OrderedDict([('Number', '101'), ('Year', '1955'), ('Album', 'In the Wee Small Hours'), ('Artist', 'Frank Sinatra'), ('Genre', 'Jazz, Pop'), ('Subgenre', 'Big Band, Ballad')])
# OrderedDict([('Number', '102'), ('Year', '1966'), ('Album', 'Fresh Cream'), ('Artist', 'Cream'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock, Electric Blues')])
# OrderedDict([('Number', '103'), ('Year', '1959'), ('Album', 'Giant Steps'), ('Artist', 'John Coltrane'), ('Genre', 'Jazz'), ('Subgenre', 'Hard Bop')])
# OrderedDict([('Number', '104'), ('Year', '1970'), ('Album', 'Sweet Baby James'), ('Artist', 'James Taylor'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Acoustic, Soft Rock')])
# OrderedDict([('Number', '105'), ('Year', '1962'), ('Album', 'Modern Sounds in Country and Western Music'), ('Artist', 'Ray Charles'), ('Genre', 'Funk / Soul, Folk, World, & Country'), ('Subgenre', 'Country, Rhythm & Blues')])
# OrderedDict([('Number', '106'), ('Year', '1977'), ('Album', 'Rocket to Russia'), ('Artist', 'Ramones'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Punk')])
# OrderedDict([('Number', '107'), ('Year', '2003'), ('Album', 'Portrait of a Legend 1951-1964'), ('Artist', 'Sam Cooke'), ('Genre', 'Latin, Funk / Soul'), ('Subgenre', 'Soul, Rhythm & Blues, Gospel, Cha-Cha')])
# OrderedDict([('Number', '108'), ('Year', '1971'), ('Album', 'Hunky Dory'), ('Artist', 'David Bowie'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Glam')])
# OrderedDict([('Number', '109'), ('Year', '1966'), ('Album', 'Aftermath'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Pop Rock')])
# OrderedDict([('Number', '110'), ('Year', '1970'), ('Album', 'Loaded'), ('Artist', 'The Velvet Underground'), ('Genre', 'Rock'), ('Subgenre', 'Art Rock, Classic Rock')])
# OrderedDict([('Number', '111'), ('Year', '1995'), ('Album', 'The Bends'), ('Artist', 'Radiohead'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '112'), ('Year', '1966'), ('Album', 'If You Can Believe Your Eyes and Ears'), ('Artist', 'The Mamas and the Papas'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Pop Rock')])
# OrderedDict([('Number', '113'), ('Year', '1974'), ('Album', 'Court and Spark'), ('Artist', 'Joni Mitchell'), ('Genre', 'Rock'), ('Subgenre', 'Soft Rock, Pop Rock')])
# OrderedDict([('Number', '114'), ('Year', '1967'), ('Album', 'Disraeli Gears'), ('Artist', 'Cream'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Blues Rock')])
# OrderedDict([('Number', '115'), ('Year', '1967'), ('Album', 'The Who Sell Out'), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Mod')])
# OrderedDict([('Number', '116'), ('Year', '1965'), ('Album', 'Out of Our Heads'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Rock & Roll')])
# OrderedDict([('Number', '117'), ('Year', '1970'), ('Album', 'Layla and Other Assorted Love Songs'), ('Artist', 'Derek and the Dominos'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '118'), ('Year', '2005'), ('Album', 'Late Registration'), ('Artist', 'Kanye West'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '119'), ('Year', '1960'), ('Album', 'At Last!'), ('Artist', 'Etta James'), ('Genre', 'Funk / Soul, Blues'), ('Subgenre', 'Rhythm & Blues, Soul')])
# OrderedDict([('Number', '120'), ('Year', '1968'), ('Album', 'Sweetheart of the Rodeo'), ('Artist', 'The Byrds'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Country Rock')])
# OrderedDict([('Number', '121'), ('Year', '1969'), ('Album', 'Stand!'), ('Artist', 'Sly & The Family Stone'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Funk, Psychedelic, Disco')])
# OrderedDict([('Number', '122'), ('Year', '1972'), ('Album', 'The Harder They Come'), ('Artist', 'Various Artists'), ('Genre', 'Reggae, Pop, Folk, World, & Country, Stage & Screen'), ('Subgenre', 'Reggae,Roots Reggae,Rocksteady,Contemporary,Soundtrack')])
# OrderedDict([('Number', '123'), ('Year', '1986'), ('Album', 'Raising Hell'), ('Artist', 'Run D.M.C.'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '124'), ('Year', '1967'), ('Album', 'Moby Grape'), ('Artist', 'Moby Grape'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Psychedelic Rock')])
# OrderedDict([('Number', '125'), ('Year', '1971'), ('Album', 'Pearl'), ('Artist', 'Janis Joplin'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '126'), ('Year', '1973'), ('Album', 'Catch a Fire'), ('Artist', 'The Wailers'), ('Genre', 'Reggae'), ('Subgenre', 'Roots Reggae')])
# OrderedDict([('Number', '127'), ('Year', '1967'), ('Album', 'Younger Than Yesterday'), ('Artist', 'The Byrds'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Psychedelic Rock')])
# OrderedDict([('Number', '128'), ('Year', '1973'), ('Album', 'Raw Power'), ('Artist', 'Iggy and The Stooges'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock, Hard Rock, Punk')])
# OrderedDict([('Number', '129'), ('Year', '1980'), ('Album', 'Remain in Light'), ('Artist', 'Talking Heads'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'New Wave, Art Rock, Funk')])
# OrderedDict([('Number', '130'), ('Year', '1977'), ('Album', 'Marquee Moon'), ('Artist', 'Television'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Punk')])
# OrderedDict([('Number', '131'), ('Year', '1970'), ('Album', 'Paranoid'), ('Artist', 'Black Sabbath'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Heavy Metal')])
# OrderedDict([('Number', '132'), ('Year', '1977'), ('Album', 'Saturday Night Fever: The Original Movie Sound Track'), ('Artist', 'Various Artists'), ('Genre', 'Electronic,Stage & Screen'), ('Subgenre', 'Soundtrack,Disco')])
# OrderedDict([('Number', '133'), ('Year', '1973'), ('Album', 'The Wild, the Innocent & the E Street Shuffle'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'None')])
# OrderedDict([('Number', '134'), ('Year', '1994'), ('Album', 'Ready to Die'), ('Artist', 'The Notorious B.I.G.'), ('Genre', 'Hip Hop'), ('Subgenre', 'Thug Rap')])
# OrderedDict([('Number', '135'), ('Year', '1992'), ('Album', 'Slanted and Enchanted'), ('Artist', 'Pavement'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '136'), ('Year', '1974'), ('Album', 'Greatest Hits'), ('Artist', 'Elton John'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '137'), ('Year', '1985'), ('Album', 'Tim'), ('Artist', 'The Replacements'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '138'), ('Year', '1992'), ('Album', 'The Chronic'), ('Artist', 'Dr. Dre'), ('Genre', 'Hip Hop'), ('Subgenre', 'Gangsta')])
# OrderedDict([('Number', '139'), ('Year', '1974'), ('Album', 'Rejuvenation'), ('Artist', 'The Meters'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Bayou Funk, Soul')])
# OrderedDict([('Number', '140'), ('Year', '1978'), ('Album', 'Parallel Lines'), ('Artist', 'Blondie'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'New Wave, Pop Rock, Punk, Disco')])
# OrderedDict([('Number', '141'), ('Year', '1965'), ('Album', 'Live at the Regal'), ('Artist', 'B.B. King'), ('Genre', 'Blues'), ('Subgenre', 'Chicago Blues')])
# OrderedDict([('Number', '142'), ('Year', '1963'), ('Album', 'A Christmas Gift for You From Phil Spector'), ('Artist', 'Phil Spector'), ('Genre', 'Rock, Funk / Soul, Pop'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '143'), ('Year', '1968'), ('Album', 'Gris-Gris'), ('Artist', 'Dr. John, the Night Tripper'), ('Genre', 'Jazz, Rock, Funk / Soul, Blues'), ('Subgenre', 'Soul-Jazz, Louisiana Blues, Fusion, Bayou Funk')])
# OrderedDict([('Number', '144'), ('Year', '1988'), ('Album', 'Straight Outta Compton'), ('Artist', 'N.W.A'), ('Genre', 'Hip Hop'), ('Subgenre', 'Gangsta')])
# OrderedDict([('Number', '145'), ('Year', '1977'), ('Album', 'Aja'), ('Artist', 'Steely Dan'), ('Genre', 'Jazz, Rock'), ('Subgenre', 'Jazz-Rock, Classic Rock')])
# OrderedDict([('Number', '146'), ('Year', '1967'), ('Album', 'Surrealistic Pillow'), ('Artist', 'Jefferson Airplane'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Psychedelic Rock')])
# OrderedDict([('Number', '147'), ('Year', '1970'), ('Album', 'Deja vu'), ('Artist', 'Crosby, Stills, Nash & Young'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '148'), ('Year', '1973'), ('Album', 'Houses of the Holy'), ('Artist', 'Led Zeppelin'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '149'), ('Year', '1969'), ('Album', 'Santana'), ('Artist', 'Santana'), ('Genre', 'Rock, Latin, Funk / Soul'), ('Subgenre', 'Afro-Cuban, Psychedelic Rock')])
# OrderedDict([('Number', '150'), ('Year', '1978'), ('Album', 'Darkness on the Edge of Town'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '151'), ('Year', '2004'), ('Album', 'Funeral'), ('Artist', 'Arcade Fire'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '152'), ('Year', '1979'), ('Album', "The B 52's / Play Loud"), ('Artist', "The B 52's"), ('Genre', 'Electronic, Rock, Pop'), ('Subgenre', 'New Wave, Punk, Mod')])
# OrderedDict([('Number', '153'), ('Year', '1991'), ('Album', 'The Low End Theory'), ('Artist', 'A Tribe Called Quest'), ('Genre', 'Hip Hop'), ('Subgenre', 'Conscious')])
# OrderedDict([('Number', '154'), ('Year', '1958'), ('Album', "Moanin' in the Moonlight"), ('Artist', "Howlin' Wolf"), ('Genre', 'Blues'), ('Subgenre', 'Chicago Blues')])
# OrderedDict([('Number', '155'), ('Year', '1980'), ('Album', 'Pretenders'), ('Artist', 'Pretenders'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, New Wave')])
# OrderedDict([('Number', '156'), ('Year', '1989'), ('Album', "Paul's Boutique"), ('Artist', 'Beastie Boys'), ('Genre', 'Hip Hop, Rock, Funk / Soul'), ('Subgenre', 'Alternative Rock, Pop Rap, Psychedelic')])
# OrderedDict([('Number', '157'), ('Year', '1980'), ('Album', 'Closer'), ('Artist', 'Joy Division'), ('Genre', 'Rock'), ('Subgenre', 'Post-Punk, New Wave')])
# OrderedDict([('Number', '158'), ('Year', '1975'), ('Album', 'Captain Fantastic and the Brown Dirt Cowboy'), ('Artist', 'Elton John'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Classic Rock')])
# OrderedDict([('Number', '159'), ('Year', '1975'), ('Album', 'Alive!'), ('Artist', 'KISS'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Glam')])
# OrderedDict([('Number', '160'), ('Year', '1971'), ('Album', 'Electric Warrior'), ('Artist', 'T. Rex'), ('Genre', 'Rock'), ('Subgenre', 'Glam, Classic Rock')])
# OrderedDict([('Number', '161'), ('Year', '1968'), ('Album', 'The Dock of the Bay'), ('Artist', 'Otis Redding'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Soul')])
# OrderedDict([('Number', '162'), ('Year', '1997'), ('Album', 'OK Computer'), ('Artist', 'Radiohead'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '163'), ('Year', '1982'), ('Album', '1999'), ('Artist', 'Prince'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '164'), ('Year', '2002'), ('Album', 'The Very Best of Linda Ronstadt'), ('Artist', 'Linda Ronstadt'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Soft Rock, Pop Rock')])
# OrderedDict([('Number', '165'), ('Year', '1973'), ('Album', "Let's Get It On"), ('Artist', 'Marvin Gaye'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '166'), ('Year', '1982'), ('Album', 'Imperial Bedroom'), ('Artist', 'Elvis Costello & The Attractions'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, New Wave')])
# OrderedDict([('Number', '167'), ('Year', '1986'), ('Album', 'Master of Puppets'), ('Artist', 'Metallica'), ('Genre', 'Rock'), ('Subgenre', 'Thrash, Speed Metal')])
# OrderedDict([('Number', '168'), ('Year', '1977'), ('Album', 'My Aim Is True'), ('Artist', 'Elvis Costello'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Pop Rock')])
# OrderedDict([('Number', '169'), ('Year', '1977'), ('Album', 'Exodus'), ('Artist', 'Bob Marley & The Wailers'), ('Genre', 'Reggae'), ('Subgenre', 'Reggae, Roots Reggae')])
# OrderedDict([('Number', '170'), ('Year', '1970'), ('Album', 'Live at Leeds'), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Blues Rock, Hard Rock')])
# OrderedDict([('Number', '171'), ('Year', '1968'), ('Album', 'The Notorious Byrd Brothers'), ('Artist', 'The Byrds'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Folk Rock, Country Rock, Pop Rock')])
# OrderedDict([('Number', '172'), ('Year', '1971'), ('Album', 'Every Picture Tells a Story'), ('Artist', 'Rod Stewart'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '173'), ('Year', '1972'), ('Album', 'Something/Anything?'), ('Artist', 'Todd Rundgren'), ('Genre', 'Rock'), ('Subgenre', 'Power Pop, Pop Rock, Prog Rock')])
# OrderedDict([('Number', '174'), ('Year', '1976'), ('Album', 'Desire'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock')])
# OrderedDict([('Number', '175'), ('Year', '1970'), ('Album', 'Close to You'), ('Artist', 'Carpenters'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Pop Rock, Vocal')])
# OrderedDict([('Number', '176'), ('Year', '1976'), ('Album', 'Rocks'), ('Artist', 'Aerosmith'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Classic Rock')])
# OrderedDict([('Number', '177'), ('Year', '1978'), ('Album', 'One Nation Under a Groove'), ('Artist', 'Funkadelic'), ('Genre', 'Funk / Soul'), ('Subgenre', 'P.Funk')])
# OrderedDict([('Number', '178'), ('Year', '1992'), ('Album', 'The Anthology: 1961-1977'), ('Artist', 'Curtis Mayfield and The Impressions'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Soul, Funk')])
# OrderedDict([('Number', '179'), ('Year', '2001'), ('Album', 'The Definitive Collection'), ('Artist', 'ABBA'), ('Genre', 'Electronic, Pop'), ('Subgenre', 'Europop, Synth-pop, Disco')])
# OrderedDict([('Number', '180'), ('Year', '1965'), ('Album', 'The Rolling Stones, Now!'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock, Blues, Pop'), ('Subgenre', 'Pop Rock, Rhythm & Blues, Rock & Roll')])
# OrderedDict([('Number', '181'), ('Year', '1974'), ('Album', 'Natty Dread'), ('Artist', 'Bob Marley & The Wailers'), ('Genre', 'Reggae'), ('Subgenre', 'Reggae, Roots Reggae')])
# OrderedDict([('Number', '182'), ('Year', '1975'), ('Album', 'Fleetwood Mac'), ('Artist', 'Fleetwood Mac'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Folk Rock, Pop Rock')])
# OrderedDict([('Number', '183'), ('Year', '1975'), ('Album', 'Red Headed Stranger'), ('Artist', 'Willie Nelson'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country')])
# OrderedDict([('Number', '184'), ('Year', '1990'), ('Album', 'The Immaculate Collection'), ('Artist', 'Madonna'), ('Genre', 'Electronic, Pop'), ('Subgenre', 'Synth-pop')])
# OrderedDict([('Number', '185'), ('Year', '1969'), ('Album', 'The Stooges'), ('Artist', 'The Stooges'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock, Punk')])
# OrderedDict([('Number', '186'), ('Year', 'nineteen seventy three'), ('Album', 'Fresh'), ('Artist', 'Sly & The Family Stone'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Funk')])
# OrderedDict([('Number', '187'), ('Year', '1986'), ('Album', 'So'), ('Artist', 'Peter Gabriel'), ('Genre', 'Electronic, Rock, Funk / Soul, Pop'), ('Subgenre', 'Art Rock, Pop Rock, Synth-pop, Funk')])
# OrderedDict([('Number', '188'), ('Year', '1967'), ('Album', 'Buffalo Springfield Again'), ('Artist', 'Buffalo Springfield'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Country Rock')])
# OrderedDict([('Number', '189'), ('Year', '1969'), ('Album', 'Happy Trails'), ('Artist', 'Quicksilver Messenger Service'), ('Genre', 'Rock'), ('Subgenre', 'Acid Rock, Psychedelic Rock')])
# OrderedDict([('Number', '190'), ('Year', '1969'), ('Album', 'From Elvis in Memphis'), ('Artist', 'Elvis Presley'), ('Genre', 'Rock, Funk / Soul, Folk, World, & Country'), ('Subgenre', 'Country, Soul')])
# OrderedDict([('Number', '191'), ('Year', '1970'), ('Album', 'Fun House'), ('Artist', 'The Stooges'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock, Punk')])
# OrderedDict([('Number', '192'), ('Year', '1969'), ('Album', 'The Gilded Palace of Sin'), ('Artist', 'The Flying Burrito Brothers'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Country Rock')])
# OrderedDict([('Number', '193'), ('Year', '1994'), ('Album', 'Dookie'), ('Artist', 'Green Day'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Pop Punk, Punk')])
# OrderedDict([('Number', '194'), ('Year', '1972'), ('Album', 'Transformer'), ('Artist', 'Lou Reed'), ('Genre', 'Rock'), ('Subgenre', 'Glam')])
# OrderedDict([('Number', '195'), ('Year', '1966'), ('Album', 'Blues Breakers With Eric Clapton ("The Beano Album")'), ('Artist', 'John Mayall & The Bluesbreakers'), ('Genre', 'Rock,Blues'), ('Subgenre', 'Blues Rock,Electric Blues,Harmonica Blues')])
# OrderedDict([('Number', '196'), ('Year', '1998'), ('Album', 'Nuggets: Original Artyfacts From the First Psychedelic Era, 1965-1968'), ('Artist', 'Various Artists'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock,Psychedelic Rock')])
# OrderedDict([('Number', '197'), ('Year', '1983'), ('Album', 'Murmur'), ('Artist', 'R.E.M.'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '198'), ('Year', '1967'), ('Album', 'The Best of Little Walter'), ('Artist', 'Little Walter'), ('Genre', 'Blues'), ('Subgenre', 'Chicago Blues')])
# OrderedDict([('Number', '199'), ('Year', '2001'), ('Album', 'Is This It'), ('Artist', 'The Strokes'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '200'), ('Year', '1979'), ('Album', 'Highway to Hell'), ('Artist', 'AC/DC'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock')])
# OrderedDict([('Number', '201'), ('Year', '1994'), ('Album', 'The Downward Spiral'), ('Artist', 'Nine Inch Nails'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Industrial')])
# OrderedDict([('Number', '202'), ('Year', '1966'), ('Album', 'Parsley, Sage, Rosemary and Thyme'), ('Artist', 'Simon & Garfunkel'), ('Genre', 'Rock, Pop, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Pop Rock')])
# OrderedDict([('Number', '203'), ('Year', '1987'), ('Album', 'Bad'), ('Artist', 'Michael Jackson'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'Pop Rock, Ballad, Funk, Soul')])
# OrderedDict([('Number', '204'), ('Year', '2006'), ('Album', 'Modern Times'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Folk Rock')])
# OrderedDict([('Number', '205'), ('Year', '1968'), ('Album', 'Wheels of Fire'), ('Artist', 'Cream'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock, Psychedelic Rock, Classic Rock')])
# OrderedDict([('Number', '206'), ('Year', '1980'), ('Album', 'Dirty Mind'), ('Artist', 'Prince'), ('Genre', 'Funk / Soul'), ('Subgenre', 'None')])
# OrderedDict([('Number', '207'), ('Year', '1970'), ('Album', 'Abraxas'), ('Artist', 'Santana'), ('Genre', 'Rock, Latin'), ('Subgenre', 'Fusion, Hard Rock, Psychedelic Rock')])
# OrderedDict([('Number', '208'), ('Year', '1970'), ('Album', 'Tea for the Tillerman'), ('Artist', 'Cat Stevens'), ('Genre', 'Rock, Stage & Screen'), ('Subgenre', 'Folk Rock, Pop Rock')])
# OrderedDict([('Number', '209'), ('Year', '1991'), ('Album', 'Ten'), ('Artist', 'Pearl Jam'), ('Genre', 'Rock'), ('Subgenre', 'Grunge')])
# OrderedDict([('Number', '210'), ('Year', '1969'), ('Album', 'Everybody Knows This Is Nowhere'), ('Artist', 'Neil Young & Crazy Horse'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Country Rock, Classic Rock')])
# OrderedDict([('Number', '211'), ('Year', '1975'), ('Album', 'Wish You Were Here'), ('Artist', 'Pink Floyd'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Prog Rock')])
# OrderedDict([('Number', '212'), ('Year', '1994'), ('Album', 'Crooked Rain Crooked Rain'), ('Artist', 'Pavement'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Indie Rock')])
# OrderedDict([('Number', '213'), ('Year', '1981'), ('Album', 'Tattoo You'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '214'), ('Year', '1991'), ('Album', 'Proud Mary: The Best of Ike and Tina Turner'), ('Artist', 'Ike & Tina Turner'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Bayou Funk, Soul')])
# OrderedDict([('Number', '215'), ('Year', '1973'), ('Album', 'New York Dolls'), ('Artist', 'New York Dolls'), ('Genre', 'Rock'), ('Subgenre', 'Glam')])
# OrderedDict([('Number', '216'), ('Year', '1986'), ('Album', 'Bo Diddley / Go Bo Diddley'), ('Artist', 'Bo Diddley'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Rhythm & Blues, Rock & Roll')])
# OrderedDict([('Number', '217'), ('Year', '1961'), ('Album', 'Two Steps From the Blues'), ('Artist', 'Bobby "Blue" Bland'), ('Genre', 'Funk / Soul, Blues'), ('Subgenre', 'Rhythm & Blues, Soul')])
# OrderedDict([('Number', '218'), ('Year', '1986'), ('Album', 'The Queen Is Dead'), ('Artist', 'The Smiths'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '219'), ('Year', '1986'), ('Album', 'Licensed to Ill'), ('Artist', 'Beastie Boys'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '220'), ('Year', '1970'), ('Album', 'Look-Ka Py Py'), ('Artist', 'The Meters'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Bayou Funk, Soul, Funk')])
# OrderedDict([('Number', '221'), ('Year', '1991'), ('Album', 'Loveless'), ('Artist', 'My Bloody Valentine'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Shoegaze')])
# OrderedDict([('Number', '222'), ('Year', '1972'), ('Album', 'New Orleans Piano'), ('Artist', 'Professor Longhair'), ('Genre', 'Funk / Soul, Blues'), ('Subgenre', 'Piano Blues')])
# OrderedDict([('Number', '223'), ('Year', '1983'), ('Album', 'War'), ('Artist', 'U2'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '224'), ('Year', '1999'), ('Album', 'The Neil Diamond Collection'), ('Artist', 'Neil Diamond'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Soft Rock, Ballad')])
# OrderedDict([('Number', '225'), ('Year', '2004'), ('Album', 'American Idiot'), ('Artist', 'Green Day'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Punk')])
# OrderedDict([('Number', '226'), ('Year', '1982'), ('Album', 'Nebraska'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Acoustic')])
# OrderedDict([('Number', '227'), ('Year', '1989'), ('Album', 'Doolittle'), ('Artist', 'Pixies'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '228'), ('Year', '1987'), ('Album', 'Paid in Full'), ('Artist', 'Eric B. & Rakim'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '229'), ('Year', '1975'), ('Album', 'Toys in the Attic'), ('Artist', 'Aerosmith'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Blues Rock')])
# OrderedDict([('Number', '230'), ('Year', '1989'), ('Album', 'Nick of Time'), ('Artist', 'Bonnie Raitt'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Blues Rock, Pop Rock')])
# OrderedDict([('Number', '231'), ('Year', '1975'), ('Album', 'A Night at the Opera'), ('Artist', 'Queen'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Pop Rock, Prog Rock')])
# OrderedDict([('Number', '232'), ('Year', '1972'), ('Album', 'The Kink Kronikles'), ('Artist', 'The Kinks'), ('Genre', 'Rock'), ('Subgenre', 'Rock & Roll, Pop Rock')])
# OrderedDict([('Number', '233'), ('Year', '1965'), ('Album', 'Mr. Tambourine Man'), ('Artist', 'The Byrds'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Garage Rock, Pop Rock')])
# OrderedDict([('Number', '234'), ('Year', '1968'), ('Album', 'Bookends'), ('Artist', 'Simon & Garfunkel'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Classic Rock')])
# OrderedDict([('Number', '235'), ('Year', '2000'), ('Album', 'The Ultimate Collection'), ('Artist', 'Patsy Cline'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'None')])
# OrderedDict([('Number', '236'), ('Year', '1992'), ('Album', 'Mr. Excitement!'), ('Artist', 'Jackie Wilson'), ('Genre', 'Funk / Soul'), ('Subgenre', 'None')])
# OrderedDict([('Number', '237'), ('Year', '1965'), ('Album', 'My Generation'), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Mod')])
# OrderedDict([('Number', '238'), ('Year', '1962'), ('Album', "Howlin' Wolf"), ('Artist', "Howlin' Wolf"), ('Genre', 'Blues'), ('Subgenre', 'None')])
# OrderedDict([('Number', '239'), ('Year', '1989'), ('Album', 'Like a Prayer'), ('Artist', 'Madonna'), ('Genre', 'Electronic, Pop'), ('Subgenre', 'Synth-pop')])
# OrderedDict([('Number', '240'), ('Year', '1972'), ('Album', "Can't Buy a Thrill"), ('Artist', 'Steely Dan'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '241'), ('Year', '1984'), ('Album', 'Let It Be'), ('Artist', 'The Replacements'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Power Pop, Punk, Indie Rock')])
# OrderedDict([('Number', '242'), ('Year', '1984'), ('Album', 'Run D.M.C.'), ('Artist', 'Run D.M.C.'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '243'), ('Year', '1970'), ('Album', 'Black Sabbath'), ('Artist', 'Black Sabbath'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Heavy Metal')])
# OrderedDict([('Number', '244'), ('Year', '2000'), ('Album', 'The Marshall Mathers LP'), ('Artist', 'Eminem'), ('Genre', 'Hip Hop'), ('Subgenre', 'Pop Rap, Hardcore Hip-Hop, Horrorcore')])
# OrderedDict([('Number', '245'), ('Year', '1993'), ('Album', 'All Killer No Filler! The Jerry Lee Lewis Anthology'), ('Artist', 'Jerry Lee Lewis'), ('Genre', 'Rock, Blues, Folk, World, & Country'), ('Subgenre', 'Country Blues, Rock & Roll, Rhythm & Blues')])
# OrderedDict([('Number', '246'), ('Year', '1966'), ('Album', 'Freak Out!'), ('Artist', 'The Mothers of Invention'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Musique Concr?te, Avantgarde, Symphonic Rock, Rhythm & Blues, Psychedelic Rock, Experimental, Parody')])
# OrderedDict([('Number', '247'), ('Year', '1969'), ('Album', 'Live/Dead'), ('Artist', 'The Grateful Dead'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Country Rock, Psychedelic Rock, Experimental')])
# OrderedDict([('Number', '248'), ('Year', '1959'), ('Album', 'The Shape of Jazz to Come'), ('Artist', 'Ornette Coleman'), ('Genre', 'Jazz'), ('Subgenre', 'Free Jazz')])
# OrderedDict([('Number', '249'), ('Year', '1992'), ('Album', 'Automatic for the People'), ('Artist', 'R.E.M.'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '250'), ('Year', '1996'), ('Album', 'Reasonable Doubt'), ('Artist', 'Jay Z'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '251'), ('Year', '1977'), ('Album', 'Low'), ('Artist', 'David Bowie'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Art Rock, Ambient, Experimental')])
# OrderedDict([('Number', '252'), ('Year', '2001'), ('Album', 'The Blueprint'), ('Artist', 'Jay Z'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '253'), ('Year', '1980'), ('Album', 'The River'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Pop Rock, Classic Rock')])
# OrderedDict([('Number', '254'), ('Year', '1966'), ('Album', 'Complete & Unbelievable: The Otis Redding Dictionary of Soul'), ('Artist', 'Otis Redding'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '255'), ('Year', '1991'), ('Album', 'Metallica ("The Black Album")'), ('Artist', 'Metallica'), ('Genre', 'Rock'), ('Subgenre', 'Heavy Metal')])
# OrderedDict([('Number', '256'), ('Year', '1977'), ('Album', 'Trans Europa Express'), ('Artist', 'Kraftwerk'), ('Genre', 'Electronic'), ('Subgenre', 'Electro')])
# OrderedDict([('Number', '257'), ('Year', '1985'), ('Album', 'Whitney Houston'), ('Artist', 'Whitney Houston'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'Synth-pop, Rhythm & Blues')])
# OrderedDict([('Number', '258'), ('Year', '1968'), ('Album', 'The Kinks Are The Village Green Preservation Society'), ('Artist', 'The Kinks'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock, Pop Rock')])
# OrderedDict([('Number', '259'), ('Year', '1997'), ('Album', 'The Velvet Rope'), ('Artist', 'Janet'), ('Genre', 'Electronic, Funk / Soul, Pop'), ('Subgenre', 'RnB/Swing, Downtempo')])
# OrderedDict([('Number', '260'), ('Year', '1978'), ('Album', 'Stardust'), ('Artist', 'Willie Nelson'), ('Genre', 'Pop, Folk, World, & Country'), ('Subgenre', 'Vocal')])
# OrderedDict([('Number', '261'), ('Year', '1970'), ('Album', 'American Beauty'), ('Artist', 'Grateful Dead'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock')])
# OrderedDict([('Number', '262'), ('Year', '1969'), ('Album', 'Crosby, Stills & Nash'), ('Artist', 'Crosby, Stills & Nash'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Classic Rock')])
# OrderedDict([('Number', '263'), ('Year', '1988'), ('Album', 'Tracy Chapman'), ('Artist', 'Tracy Chapman'), ('Genre', 'Rock'), ('Subgenre', 'None')])
# OrderedDict([('Number', '264'), ('Year', '1970'), ('Album', "Workingman's Dead"), ('Artist', 'Grateful Dead'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Country Rock, Classic Rock')])
# OrderedDict([('Number', '265'), ('Year', '1959'), ('Album', 'The Genius of Ray Charles'), ('Artist', 'Ray Charles'), ('Genre', 'Jazz, Pop'), ('Subgenre', 'Soul-Jazz, Big Band')])
# OrderedDict([('Number', '266'), ('Year', '1968'), ('Album', 'Child Is Father to the Man'), ('Artist', 'Blood, Sweat & Tears'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Jazz-Rock, Classic Rock')])
# OrderedDict([('Number', '267'), ('Year', '1973'), ('Album', 'Quadrophenia'), ('Artist', 'The Who'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Classic Rock, Mod')])
# OrderedDict([('Number', '268'), ('Year', '1972'), ('Album', 'Paul Simon'), ('Artist', 'Paul Simon'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Pop Rock')])
# OrderedDict([('Number', '269'), ('Year', '1985'), ('Album', 'Psychocandy'), ('Artist', 'The Jesus and Mary Chain'), ('Genre', 'Rock'), ('Subgenre', 'Noise')])
# OrderedDict([('Number', '270'), ('Year', '1978'), ('Album', 'Some Girls'), ('Artist', 'The Rolling Stones'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Rock & Roll, Classic Rock, Disco')])
# OrderedDict([('Number', '271'), ('Year', '1965'), ('Album', 'The Beach Boys Today!'), ('Artist', 'The Beach Boys'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Psychedelic Rock')])
# OrderedDict([('Number', '272'), ('Year', '1997'), ('Album', 'Dig Me Out'), ('Artist', 'Sleater Kinney'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '273'), ('Year', '1966'), ('Album', 'Going to a Go-Go'), ('Artist', 'Smokey Robinson & The Miracles'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '274'), ('Year', '1974'), ('Album', 'Nightbirds'), ('Artist', 'LaBelle'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Funk, Disco')])
# OrderedDict([('Number', '275'), ('Year', '1999'), ('Album', 'The Slim Shady LP'), ('Artist', 'Eminem'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# ...
# OrderedDict([('Number', '408'), ('Year', '1989'), ('Album', "I Do Not Want What I Haven't Got"), ('Artist', "Sinead O'Connor"), ('Genre', 'Rock, Funk / Soul, Blues'), ('Subgenre', 'Blues Rock, Rhythm & Blues, Soul')])
# OrderedDict([('Number', '409'), ('Year', '1967'), ('Album', 'Strange Days'), ('Artist', 'The Doors'), ('Genre', 'Rock'), ('Subgenre', 'Psychedelic Rock')])
# OrderedDict([('Number', '410'), ('Year', '1997'), ('Album', 'Time Out of Mind'), ('Artist', 'Bob Dylan'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '411'), ('Year', '1974'), ('Album', '461 Ocean Boulevard'), ('Artist', 'Eric Clapton'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '412'), ('Year', '1977'), ('Album', 'Pink Flag'), ('Artist', 'Wire'), ('Genre', 'Rock'), ('Subgenre', 'Punk')])
# OrderedDict([('Number', '413'), ('Year', '1984'), ('Album', 'Double Nickels on the Dime'), ('Artist', 'Minutemen'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Hardcore, Punk')])
# OrderedDict([('Number', '414'), ('Year', '1981'), ('Album', 'Beauty and the Beat'), ('Artist', "The Go Go's"), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '415'), ('Year', '1978'), ('Album', 'Van Halen'), ('Artist', 'Van Halen'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock')])
# OrderedDict([('Number', '416'), ('Year', '1999'), ('Album', 'Mule Variations'), ('Artist', 'Tom Waits'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Abstract, Art Rock')])
# OrderedDict([('Number', '417'), ('Year', '1980'), ('Album', 'Boy'), ('Artist', 'U2'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Pop Rock')])
# OrderedDict([('Number', '418'), ('Year', '1973'), ('Album', 'Band on the Run'), ('Artist', 'Paul McCartney & Wings'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '419'), ('Year', '1994'), ('Album', 'Dummy'), ('Artist', 'Portishead'), ('Genre', 'Electronic'), ('Subgenre', 'Trip Hop, Downtempo')])
# OrderedDict([('Number', '420'), ('Year', '1957'), ('Album', 'The "Chirping" Crickets'), ('Artist', 'The Crickets'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Rockabilly, Rock & Roll')])
# OrderedDict([('Number', '421'), ('Year', '1990'), ('Album', 'The Best of the Girl Groups, Volume 1'), ('Artist', 'Various Artists'), ('Genre', 'Rock,Pop'), ('Subgenre', 'Pop Rock, Vocal')])
# OrderedDict([('Number', '422'), ('Year', '1963'), ('Album', 'Presenting the Fabulous Ronettes Featuring Veronica'), ('Artist', 'The Ronettes'), ('Genre', 'Rock, Pop'), ('Subgenre', 'Rock & Roll, Vocal')])
# OrderedDict([('Number', '423'), ('Year', '2001'), ('Album', 'Anthology'), ('Artist', 'Diana Ross & The Supremes'), ('Genre', 'Electronic, Funk / Soul'), ('Subgenre', 'Pop Rock, Soul, Disco')])
# OrderedDict([('Number', '424'), ('Year', '2002'), ('Album', 'The Rising'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'Folk Rock, Classic Rock')])
# OrderedDict([('Number', '425'), ('Year', '1974'), ('Album', 'Grievous Angel'), ('Artist', 'Gram Parsons'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Country Rock, Honky Tonk')])
# OrderedDict([('Number', '426'), ('Year', '1978'), ('Album', 'Cheap Trick at Budokan'), ('Artist', 'Cheap Trick'), ('Genre', 'Rock'), ('Subgenre', 'Power Pop, Pop Rock, Arena Rock, Hard Rock')])
# OrderedDict([('Number', '427'), ('Year', '2002'), ('Album', 'Sleepless'), ('Artist', 'Peter Wolf'), ('Genre', 'Rock, Blues, Pop'), ('Subgenre', 'Blues Rock, Pop Rock, Ballad')])
# OrderedDict([('Number', '428'), ('Year', '1978'), ('Album', "Outlandos d'Amour"), ('Artist', 'The Police'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, New Wave, Punk')])
# OrderedDict([('Number', '429'), ('Year', '1975'), ('Album', 'Another Green World'), ('Artist', 'Brian Eno'), ('Genre', 'Electronic'), ('Subgenre', 'Experimental, Ambient')])
# OrderedDict([('Number', '430'), ('Year', '2007'), ('Album', 'Vampire Weekend'), ('Artist', 'Vampire Weekend'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '431'), ('Year', '2000'), ('Album', 'Stories From the City, Stories From the Sea'), ('Artist', 'PJ Harvey'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '432'), ('Year', '1973'), ('Album', 'Here Come the Warm Jets'), ('Artist', 'Brian Eno'), ('Genre', 'Rock'), ('Subgenre', 'Art Rock, Glam')])
# OrderedDict([('Number', '433'), ('Year', '1970'), ('Album', 'All Things Must Pass'), ('Artist', 'George Harrison'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '434'), ('Year', '1972'), ('Album', '#1 Record'), ('Artist', 'Big Star'), ('Genre', 'Rock'), ('Subgenre', 'Power Pop')])
# OrderedDict([('Number', '435'), ('Year', '1993'), ('Album', 'In Utero'), ('Artist', 'Nirvana'), ('Genre', 'Rock'), ('Subgenre', 'Grunge, Alternative Rock')])
# OrderedDict([('Number', '436'), ('Year', '2002'), ('Album', 'Sea Change'), ('Artist', 'Beck'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Post Rock')])
# OrderedDict([('Number', '437'), ('Year', '2008'), ('Album', 'Tha Carter III'), ('Artist', 'Lil Wayne'), ('Genre', 'Hip Hop, Funk / Soul'), ('Subgenre', 'RnB/Swing, Screw, Pop Rap, Thug Rap')])
# OrderedDict([('Number', '438'), ('Year', '1979'), ('Album', "Boys Don't Cry"), ('Artist', 'The Cure'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Post-Punk')])
# OrderedDict([('Number', '439'), ('Year', '1985'), ('Album', 'Live at the Harlem Square Club, 1963'), ('Artist', 'Sam Cooke'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '440'), ('Year', '1985'), ('Album', 'Rum Sodomy & the Lash'), ('Artist', 'The Pogues'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Folk Rock, Celtic, Punk')])
# OrderedDict([('Number', '441'), ('Year', '1977'), ('Album', 'Suicide'), ('Artist', 'Suicide'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'New Wave, Experimental')])
# OrderedDict([('Number', '442'), ('Year', '1978'), ('Album', 'Q: Are We Not Men? A: We Are Devo!'), ('Artist', 'DEVO'), ('Genre', 'Rock'), ('Subgenre', 'New Wave')])
# OrderedDict([('Number', '443'), ('Year', '1977'), ('Album', 'In Color'), ('Artist', 'Cheap Trick'), ('Genre', 'Rock'), ('Subgenre', 'Power Pop, Pop Rock, Hard Rock')])
# OrderedDict([('Number', '444'), ('Year', '1972'), ('Album', 'The World Is a Ghetto'), ('Artist', 'War'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Funk')])
# OrderedDict([('Number', '445'), ('Year', '1976'), ('Album', 'Fly Like an Eagle'), ('Artist', 'Steve Miller Band'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '446'), ('Year', '1970'), ('Album', 'Back in the USA'), ('Artist', 'MC5'), ('Genre', 'Rock'), ('Subgenre', 'Garage Rock, Rock & Roll')])
# OrderedDict([('Number', '447'), ('Year', '1964'), ('Album', 'Getz / Gilberto'), ('Artist', 'Stan Getz/Joao GilbertofeaturingAntonio Carlos Jobim'), ('Genre', 'Jazz'), ('Subgenre', 'Bossa Nova,Latin Jazz')])
# OrderedDict([('Number', '448'), ('Year', '1983'), ('Album', 'Synchronicity'), ('Artist', 'The Police'), ('Genre', 'Rock, Pop'), ('Subgenre', 'New Wave, Pop Rock')])
# OrderedDict([('Number', '449'), ('Year', '1978'), ('Album', 'Third/Sister Lovers'), ('Artist', 'Big Star'), ('Genre', 'Rock'), ('Subgenre', 'Lo-Fi,Indie Rock')])
# OrderedDict([('Number', '450'), ('Year', '1973'), ('Album', 'For Everyman'), ('Artist', 'Jackson Browne'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock, Classic Rock')])
# OrderedDict([('Number', '451'), ('Year', '2006'), ('Album', 'Back to Black'), ('Artist', 'Amy Winehouse'), ('Genre', 'Funk / Soul, Pop'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '452'), ('Year', '1971'), ('Album', 'John Prine'), ('Artist', 'John Prine'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country, Folk')])
# OrderedDict([('Number', '453'), ('Year', '1987'), ('Album', 'Strictly Business'), ('Artist', 'EPMD'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '454'), ('Year', '1971'), ('Album', 'Love It to Death'), ('Artist', 'Alice Cooper'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock')])
# OrderedDict([('Number', '455'), ('Year', '1984'), ('Album', 'How Will the Wolf Survive?'), ('Artist', 'Los Lobos'), ('Genre', 'Rock, Latin'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '456'), ('Year', '1978'), ('Album', 'Here, My Dear'), ('Artist', 'Marvin Gaye'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul')])
# OrderedDict([('Number', '457'), ('Year', '2005'), ('Album', 'Z'), ('Artist', 'My Morning Jacket'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '458'), ('Year', '1970'), ('Album', 'Tumbleweed Connection'), ('Artist', 'Elton John'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Soft Rock, Country Rock')])
# OrderedDict([('Number', '459'), ('Year', '1968'), ('Album', "The Drifters' Golden Hits"), ('Artist', 'The Drifters'), ('Genre', 'Rock, Funk / Soul'), ('Subgenre', 'Rhythm & Blues, Soul')])
# OrderedDict([('Number', '460'), ('Year', '1994'), ('Album', 'Live Through This'), ('Artist', 'Hole'), ('Genre', 'Rock'), ('Subgenre', 'Grunge')])
# OrderedDict([('Number', '461'), ('Year', '1979'), ('Album', 'Metal Box'), ('Artist', 'Public Image Ltd.'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Post-Punk, Dub, Avantgarde, Experimental')])
# OrderedDict([('Number', '462'), ('Year', '1987'), ('Album', 'Document'), ('Artist', 'R.E.M.'), ('Genre', 'Rock'), ('Subgenre', 'None')])
# OrderedDict([('Number', '463'), ('Year', '1981'), ('Album', 'Heaven Up Here'), ('Artist', 'Echo and The Bunnymen'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Indie Rock')])
# OrderedDict([('Number', '464'), ('Year', '1987'), ('Album', 'Hysteria'), ('Artist', 'Def Leppard'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock, Arena Rock')])
# OrderedDict([('Number', '465'), ('Year', '1999'), ('Album', '69 Love Songs'), ('Artist', 'The Magnetic Fields'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Synth-pop, Indie Rock')])
# OrderedDict([('Number', '466'), ('Year', '2002'), ('Album', 'A Rush of Blood to the Head'), ('Artist', 'Coldplay'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Pop Rock')])
# OrderedDict([('Number', '467'), ('Year', '1987'), ('Album', 'Tunnel of Love'), ('Artist', 'Bruce Springsteen'), ('Genre', 'Rock'), ('Subgenre', 'None')])
# OrderedDict([('Number', '468'), ('Year', '1965'), ('Album', 'The Paul Butterfield Blues Band'), ('Artist', 'The Paul Butterfield Blues Band'), ('Genre', 'Rock, Blues'), ('Subgenre', 'Blues Rock, Electric Blues, Chicago Blues, Modern Electric Blues, Harmonica Blues')])
# OrderedDict([('Number', '469'), ('Year', '1996'), ('Album', 'The Score'), ('Artist', 'Fugees'), ('Genre', 'Hip Hop'), ('Subgenre', 'Pop Rap, Conscious')])
# OrderedDict([('Number', '470'), ('Year', '1985'), ('Album', 'Radio'), ('Artist', 'L.L. Cool J'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '471'), ('Year', '1974'), ('Album', 'I Want to See the Bright Lights Tonight'), ('Artist', 'Richard & Linda Thompson'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Folk Rock')])
# OrderedDict([('Number', '472'), ('Year', '1987'), ('Album', 'Faith'), ('Artist', 'George Michael'), ('Genre', 'Electronic, Rock, Funk / Soul, Blues, Pop'), ('Subgenre', 'Downtempo, Soft Rock, Pop Rock, Synth-pop')])
# OrderedDict([('Number', '473'), ('Year', '1984'), ('Album', 'The Smiths'), ('Artist', 'The Smiths'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '474'), ('Year', '2001'), ('Album', 'Proxima estacion: Esperanza'), ('Artist', 'Manu Chao'), ('Genre', 'Rock, Reggae, Latin'), ('Subgenre', 'Folk Rock, Reggae, Reggae-Pop')])
# OrderedDict([('Number', '475'), ('Year', '1979'), ('Album', 'Armed Forces'), ('Artist', 'Elvis Costello & The Attractions'), ('Genre', 'Rock'), ('Subgenre', 'New Wave, Pop Rock')])
# OrderedDict([('Number', '476'), ('Year', '1997'), ('Album', 'Life After Death'), ('Artist', 'The Notorious B.I.G.'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '477'), ('Year', '1996'), ('Album', 'Down Every Road'), ('Artist', 'Merle Haggard'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country')])
# OrderedDict([('Number', '478'), ('Year', '2002'), ('Album', 'All Time Greatest Hits'), ('Artist', 'Loretta Lynn'), ('Genre', 'Folk, World, & Country'), ('Subgenre', 'Country')])
# OrderedDict([('Number', '479'), ('Year', '1971'), ('Album', 'Maggot Brain'), ('Artist', 'Funkadelic'), ('Genre', 'Rock, Funk / Soul'), ('Subgenre', 'P.Funk, Psychedelic Rock')])
# OrderedDict([('Number', '480'), ('Year', '1995'), ('Album', 'Only Built 4 Cuban Linx'), ('Artist', 'Raekwon'), ('Genre', 'Hip Hop'), ('Subgenre', 'None')])
# OrderedDict([('Number', '481'), ('Year', '2000'), ('Album', 'Voodoo'), ('Artist', "D'Angelo"), ('Genre', 'Hip Hop, Funk / Soul'), ('Subgenre', 'Soul, Funk, Neo Soul')])
# OrderedDict([('Number', '482'), ('Year', '1986'), ('Album', 'Guitar Town'), ('Artist', 'Steve Earle'), ('Genre', 'Rock, Folk, World, & Country'), ('Subgenre', 'Country, Honky Tonk')])
# OrderedDict([('Number', '483'), ('Year', '1979'), ('Album', 'Entertainment!'), ('Artist', 'Gang of Four'), ('Genre', 'Rock'), ('Subgenre', 'Post-Punk, New Wave')])
# OrderedDict([('Number', '484'), ('Year', '1972'), ('Album', 'All the Young Dudes'), ('Artist', 'Mott the Hoople'), ('Genre', 'Rock'), ('Subgenre', 'Classic Rock, Glam')])
# OrderedDict([('Number', '485'), ('Year', '1994'), ('Album', 'Vitalogy'), ('Artist', 'Pearl Jam'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Hard Rock')])
# OrderedDict([('Number', '486'), ('Year', '1975'), ('Album', "That's the Way of the World"), ('Artist', 'Earth, Wind & Fire'), ('Genre', 'Funk / Soul'), ('Subgenre', 'Soul, Funk, Disco')])
# OrderedDict([('Number', '487'), ('Year', '1983'), ('Album', "She's So Unusual"), ('Artist', 'Cyndi Lauper'), ('Genre', 'Electronic, Rock'), ('Subgenre', 'Pop Rock, Synth-pop')])
# OrderedDict([('Number', '488'), ('Year', '1985'), ('Album', 'New Day Rising'), ('Artist', 'Husker Du'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock, Hardcore, Punk')])
# OrderedDict([('Number', '489'), ('Year', '1976'), ('Album', 'Destroyer'), ('Artist', 'KISS'), ('Genre', 'Rock'), ('Subgenre', 'Hard Rock')])
# OrderedDict([('Number', '490'), ('Year', '1973'), ('Album', 'Tres hombres'), ('Artist', 'ZZ Top'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock, Classic Rock')])
# OrderedDict([('Number', '491'), ('Year', '1967'), ('Album', 'Born Under a Bad Sign'), ('Artist', 'Albert King'), ('Genre', 'Funk / Soul, Blues'), ('Subgenre', 'Electric Blues, Rhythm & Blues, Soul')])
# OrderedDict([('Number', '492'), ('Year', '1983'), ('Album', 'Touch'), ('Artist', 'Eurythmics'), ('Genre', 'Electronic, Pop'), ('Subgenre', 'New Wave, Synth-pop')])
# OrderedDict([('Number', '493'), ('Year', '2002'), ('Album', 'Yankee Hotel Foxtrot'), ('Artist', 'Wilco'), ('Genre', 'Rock'), ('Subgenre', 'Alternative Rock')])
# OrderedDict([('Number', '494'), ('Year', '2007'), ('Album', 'Oracular Spectacular'), ('Artist', 'MGMT'), ('Genre', 'Electronic, Rock, Pop'), ('Subgenre', 'Synth-pop, Indie Rock')])
# OrderedDict([('Number', '495'), ('Year', '1972'), ('Album', 'Give It Up'), ('Artist', 'Bonnie Raitt'), ('Genre', 'Rock'), ('Subgenre', 'Blues Rock')])
# OrderedDict([('Number', '496'), ('Year', '1969'), ('Album', 'Boz Scaggs'), ('Artist', 'Boz Scaggs'), ('Genre', 'Rock'), ('Subgenre', 'Pop Rock')])
# OrderedDict([('Number', '497'), ('Year', '2001'), ('Album', 'White Blood Cells'), ('Artist', 'The White Stripes'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock, Alternative Rock, Blues Rock, Garage Rock')])
# OrderedDict([('Number', '498'), ('Year', '1989'), ('Album', 'The Stone Roses'), ('Artist', 'The Stone Roses'), ('Genre', 'Rock'), ('Subgenre', 'Indie Rock')])
# OrderedDict([('Number', '499'), ('Year', '1971'), ('Album', 'Live in Cook County Jail'), ('Artist', 'B.B. King'), ('Genre', 'Blues'), ('Subgenre', 'Electric Blues')])
# OrderedDict([('Number', '500'), ('Year', '1998'), ('Album', 'Aquemini'), ('Artist', 'OutKast'), ('Genre', 'Hip Hop'), ('Subgenre', 'Reggae, Gangsta, Soul, Conscious')])

# %%
with open('albumlist.csv','r') as csvfile:
  reader = csv.DictReader(csvfile)

  album =[]
  for row in reader:
    album.append(row)

    print('number album: ',len(album))
# Out:
# number album:  1
# number album:  2
# number album:  3
# number album:  4
# number album:  5
# number album:  6
# number album:  7
# number album:  8
# number album:  9
# number album:  10
# number album:  11
# number album:  12
# number album:  13
# number album:  14
# number album:  15
# number album:  16
# number album:  17
# number album:  18
# number album:  19
# number album:  20
# number album:  21
# number album:  22
# number album:  23
# number album:  24
# number album:  25
# number album:  26
# number album:  27
# number album:  28
# number album:  29
# number album:  30
# number album:  31
# number album:  32
# number album:  33
# number album:  34
# number album:  35
# number album:  36
# number album:  37
# number album:  38
# number album:  39
# number album:  40
# number album:  41
# number album:  42
# number album:  43
# number album:  44
# number album:  45
# number album:  46
# number album:  47
# number album:  48
# number album:  49
# number album:  50
# number album:  51
# number album:  52
# number album:  53
# number album:  54
# number album:  55
# number album:  56
# number album:  57
# number album:  58
# number album:  59
# number album:  60
# number album:  61
# number album:  62
# number album:  63
# number album:  64
# number album:  65
# number album:  66
# number album:  67
# number album:  68
# number album:  69
# number album:  70
# number album:  71
# number album:  72
# number album:  73
# number album:  74
# number album:  75
# number album:  76
# number album:  77
# number album:  78
# number album:  79
# number album:  80
# number album:  81
# number album:  82
# number album:  83
# number album:  84
# number album:  85
# number album:  86
# number album:  87
# number album:  88
# number album:  89
# number album:  90
# number album:  91
# number album:  92
# number album:  93
# number album:  94
# number album:  95
# number album:  96
# number album:  97
# number album:  98
# number album:  99
# number album:  100
# number album:  101
# number album:  102
# number album:  103
# number album:  104
# number album:  105
# number album:  106
# number album:  107
# number album:  108
# number album:  109
# number album:  110
# number album:  111
# number album:  112
# number album:  113
# number album:  114
# number album:  115
# number album:  116
# number album:  117
# number album:  118
# number album:  119
# number album:  120
# number album:  121
# number album:  122
# number album:  123
# number album:  124
# number album:  125
# number album:  126
# number album:  127
# number album:  128
# number album:  129
# number album:  130
# number album:  131
# number album:  132
# number album:  133
# number album:  134
# number album:  135
# number album:  136
# number album:  137
# number album:  138
# number album:  139
# number album:  140
# number album:  141
# number album:  142
# number album:  143
# number album:  144
# number album:  145
# number album:  146
# number album:  147
# number album:  148
# number album:  149
# number album:  150
# number album:  151
# number album:  152
# number album:  153
# number album:  154
# number album:  155
# number album:  156
# number album:  157
# number album:  158
# number album:  159
# number album:  160
# number album:  161
# number album:  162
# number album:  163
# number album:  164
# number album:  165
# number album:  166
# number album:  167
# number album:  168
# number album:  169
# number album:  170
# number album:  171
# number album:  172
# number album:  173
# number album:  174
# number album:  175
# number album:  176
# number album:  177
# number album:  178
# number album:  179
# number album:  180
# number album:  181
# number album:  182
# number album:  183
# number album:  184
# number album:  185
# number album:  186
# number album:  187
# number album:  188
# number album:  189
# number album:  190
# number album:  191
# number album:  192
# number album:  193
# number album:  194
# number album:  195
# number album:  196
# number album:  197
# number album:  198
# number album:  199
# number album:  200
# number album:  201
# number album:  202
# number album:  203
# number album:  204
# number album:  205
# number album:  206
# number album:  207
# number album:  208
# number album:  209
# number album:  210
# number album:  211
# number album:  212
# number album:  213
# number album:  214
# number album:  215
# number album:  216
# number album:  217
# number album:  218
# number album:  219
# number album:  220
# number album:  221
# number album:  222
# number album:  223
# number album:  224
# number album:  225
# number album:  226
# number album:  227
# number album:  228
# number album:  229
# number album:  230
# number album:  231
# number album:  232
# number album:  233
# number album:  234
# number album:  235
# number album:  236
# number album:  237
# number album:  238
# number album:  239
# number album:  240
# number album:  241
# number album:  242
# number album:  243
# number album:  244
# number album:  245
# number album:  246
# number album:  247
# number album:  248
# number album:  249
# number album:  250
# number album:  251
# number album:  252
# number album:  253
# number album:  254
# number album:  255
# number album:  256
# number album:  257
# number album:  258
# number album:  259
# number album:  260
# number album:  261
# number album:  262
# number album:  263
# number album:  264
# number album:  265
# number album:  266
# number album:  267
# number album:  268
# number album:  269
# number album:  270
# number album:  271
# number album:  272
# number album:  273
# number album:  274
# number album:  275
# number album:  276
# number album:  277
# number album:  278
# number album:  279
# number album:  280
# number album:  281
# number album:  282
# number album:  283
# number album:  284
# number album:  285
# number album:  286
# number album:  287
# number album:  288
# number album:  289
# number album:  290
# number album:  291
# number album:  292
# number album:  293
# number album:  294
# number album:  295
# number album:  296
# number album:  297
# number album:  298
# number album:  299
# number album:  300
# number album:  301
# number album:  302
# number album:  303
# number album:  304
# number album:  305
# number album:  306
# number album:  307
# number album:  308
# number album:  309
# number album:  310
# number album:  311
# number album:  312
# number album:  313
# number album:  314
# number album:  315
# number album:  316
# number album:  317
# number album:  318
# number album:  319
# number album:  320
# number album:  321
# number album:  322
# number album:  323
# number album:  324
# number album:  325
# number album:  326
# number album:  327
# number album:  328
# number album:  329
# number album:  330
# number album:  331
# number album:  332
# number album:  333
# number album:  334
# number album:  335
# number album:  336
# number album:  337
# number album:  338
# number album:  339
# number album:  340
# number album:  341
# number album:  342
# number album:  343
# number album:  344
# number album:  345
# number album:  346
# number album:  347
# number album:  348
# number album:  349
# number album:  350
# number album:  351
# number album:  352
# number album:  353
# number album:  354
# number album:  355
# number album:  356
# number album:  357
# number album:  358
# number album:  359
# number album:  360
# number album:  361
# number album:  362
# number album:  363
# number album:  364
# number album:  365
# number album:  366
# number album:  367
# number album:  368
# number album:  369
# number album:  370
# number album:  371
# number album:  372
# number album:  373
# number album:  374
# number album:  375
# number album:  376
# number album:  377
# number album:  378
# number album:  379
# number album:  380
# number album:  381
# number album:  382
# number album:  383
# number album:  384
# number album:  385
# number album:  386
# number album:  387
# number album:  388
# number album:  389
# number album:  390
# number album:  391
# number album:  392
# number album:  393
# number album:  394
# number album:  395
# number album:  396
# number album:  397
# number album:  398
# number album:  399
# number album:  400
# number album:  401
# number album:  402
# number album:  403
# number album:  404
# number album:  405
# number album:  406
# number album:  407
# number album:  408
# number album:  409
# number album:  410
# number album:  411
# number album:  412
# number album:  413
# number album:  414
# number album:  415
# number album:  416
# number album:  417
# number album:  418
# number album:  419
# number album:  420
# number album:  421
# number album:  422
# number album:  423
# number album:  424
# number album:  425
# number album:  426
# number album:  427
# number album:  428
# number album:  429
# number album:  430
# number album:  431
# number album:  432
# number album:  433
# number album:  434
# number album:  435
# number album:  436
# number album:  437
# number album:  438
# number album:  439
# number album:  440
# number album:  441
# number album:  442
# number album:  443
# number album:  444
# number album:  445
# number album:  446
# number album:  447
# number album:  448
# number album:  449
# number album:  450
# number album:  451
# number album:  452
# number album:  453
# number album:  454
# number album:  455
# number album:  456
# number album:  457
# number album:  458
# number album:  459
# number album:  460
# number album:  461
# number album:  462
# number album:  463
# number album:  464
# number album:  465
# number album:  466
# number album:  467
# number album:  468
# number album:  469
# number album:  470
# number album:  471
# number album:  472
# number album:  473
# number album:  474
# number album:  475
# number album:  476
# number album:  477
# number album:  478
# number album:  479
# number album:  480
# number album:  481
# number album:  482
# number album:  483
# number album:  484
# number album:  485
# number album:  486
# number album:  487
# number album:  488
# number album:  489
# number album:  490
# number album:  491
# number album:  492
# number album:  493
# number album:  494
# number album:  495
# number album:  496
# number album:  497
# number album:  498
# number album:  499
# number album:  500
